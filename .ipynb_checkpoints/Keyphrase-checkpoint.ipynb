# %% [markdown]
# #NLP ASSIGNMENT

# %%
import nltk 
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import state_union
from nltk.tokenize import  PunktSentenceTokenizer
from string import punctuation
import re
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

# %%
# Tokenizing and processing text 
stop_word= set(stopwords.words("english"))
def tokenize_text(corpus):
    sent_tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
    raw_sents = sent_tokenizer.tokenize(corpus) # Split text into sentences 
    word_token= [nltk.word_tokenize(word) for word in raw_sents]
    cleaned=[]
    for sent in word_token:
        clean= [word.lower() for word in sent if word.lower() not in stop_word 
                and word.lower() not in punctuation 
                and not re.search(r'''^[\.,;"'?!():\-_`]+$''', word.lower())]
        cleaned.append(clean)
    return cleaned
    
    return word_token
myst=open ("mystery_text_expository_2016.txt")
SOU= ) #Using the State of the Union Corpus

token_SOU= tokenize_text(SOU)

# %%
def lemma(sents): #Lemmatizing the  words 
    tagged_POS_sents = [nltk.pos_tag(sent) for sent in sents]
    lemma= WordNetLemmatizer()
    word_lemma=[]
    for sent in tagged_POS_sents:
        intermediary=[]
        for word in sent: # Lemmatising according to the POS to maintain integrity of meaning
            if word[1][:2] == "NN" or word[1][:2] == "JJ" or word[1][:2] == "VB" or word[1][:2] == "RB":  
                lemma_tag = {'NN':wordnet.NOUN,'JJ':wordnet.ADJ,'VB':wordnet.VERB,'RB':wordnet.ADV}
                intermediary.append(lemma.lemmatize(word[0], pos=lemma_tag[word[1][:2]]))
            else:
               intermediary.append(lemma.lemmatize(word[0]))
        word_lemma.append(intermediary)
    return word_lemma
                                  
a= lemma(token_SOU)
lemmatised_pos= [nltk.pos_tag(sent) for sent in a]

# %%
def chunking(lemmatised_pos): #Chunking 
    try:
        tree=[]
        for i in lemmatised_pos:
            grammar = r"""NP: {<JJ|NN>+<NN|CD|NN>}   """
            cp = nltk.RegexpParser(grammar)
            tag=cp.parse(i)
            tree.append(tag)
        return tree
        
    except Exception as e:
        pass
       # print (str(e))
             
b= chunking(lemmatised_pos)
# Out:
# Warning: parsing empty text

# %%
#Most common noun phrase and words describing the text 
"""from nltk.stem import PorterStemmer 
ps= PorterStemmer()"""
#stemmed = [ps.stem(w) for w in sample]
word_np= []
#Identifying major noun phrase
sent_np=[]
for n in b:
    word=[]
    for sent in n:
        if isinstance(sent, nltk.tree.Tree): 
            if sent.label()== 'NP':
                 word_np.append((sent[0][0]))
                 #word_np.append(sent[0][0])
            else:
                pass
    sent_np.append(word)

c=nltk.FreqDist(word_np).most_common(3000)
c_list=[]
for i in c:
    if i>=2 and len(i[0])>=2:
        print i[0]
        c_list.append(i[0])
#len(word_np)
print len(c_list)
# Out:
# america
# american
# tonight
# great
# president
# hopeful
# year
# offensive
# state
# new
# white
# lead
# united
# choose
# nation
# terrorist
# government
# way
# difference
# social
# military
# honor
# high
# economy
# day
# urge
# confident
# life
# member
# temporary
# know
# economic
# fellow
# grateful
# join
# dictatorship
# large
# liberty
# egypt
# use
# call
# history
# tax
# democracy
# renew
# end
# permanent
# math
# standard
# iranian
# youth
# sure
# crime
# national
# federal
# last
# point
# interest
# child
# party
# hand
# recent
# alternative
# early
# world
# broad
# power
# dangerous
# medical
# deep
# peace
# percent
# time
# serious
# forget
# lack
# dynamic
# chaos
# laura
# debris
# welfare
# concerned
# environment
# iraqi
# program
# excluded
# woman
# compassion
# rise
# choice
# trouble
# school
# level
# ryan
# adjust
# upper
# pledge
# cost
# pass
# constitution
# uniform
# appeal
# full
# poverty
# ethanol
# address
# path
# change
# wait
# talent
# prior
# elect
# secure
# danger
# palestinian
# destination
# next
# few
# strike
# today
# israel
# baby
# glad
# word
# pursue
# work
# coalition
# meet
# court
# provide
# write
# vital
# answer
# sacrifice
# vicious
# reflect
# law
# natural
# allow
# african
# democratic
# help
# thank
# consequential
# main
# zero-emission
# propose
# dan
# milestone
# republican
# flee
# strive
# bless
# found
# upward
# everyone
# truman
# insurance
# special
# category
# quality
# factory
# research
# increase
# health
# cause
# belief
# matchless
# ask
# marine
# keep
# turn
# hopeless
# first
# major
# impossible
# open
# unknown
# system
# attack
# storm
# destruction
# friend
# murder
# immediate
# wisdom
# institution
# future
# historical
# strengthen
# modern
# seek
# prosperity
# ideal
# build
# roadside
# reach
# letter
# nothing
# deny
# clear
# gather
# face
# clean
# professional
# show
# fear
# pleased
# decade
# staff
# justice
# bush
# hope
# hostage
# import
# humbled
# enemy
# resource
# bad
# troop
# ethical
# declared
# disaster
# desperate
# superb
# progress
# europe
# retirement
# lawsuit
# country
# drug
# let
# tough
# wall
# resentment
# wider
# respect
# line-item
# raise
# capable
# come
# create
# much
# commuter
# dismiss
# worker
# fund
# dramatic
# spirit
# present
# petroleum-based
# look
# doctor-patient
# promising
# aid
# middle
# sudden
# optimistic
# worry
# capture
# patent
# out-produce
# complex
# finish
# iraqis
# weapon
# constitutional
# money
# half
# violent
# birmingham
# human
# previous
# death
# character
# easy
# citizen
# east
# unprecedented
# bin
# miscalculate
# big
# zimbabwe
# short-changing
# mom
# lady
# desire
# like
# confront
# chamber
# continue
# lose
# essential
# fulfil
# battlefield
# old
# captive
# election
# escape
# home
# decision
# creative
# deficit
# leader
# bold
# martin
# expire
# anything
# freedom
# dependence
# act
# road
# commitment
# appropriate
# additional
# prepare
# area
# support
# fight
# start
# greatness
# decisive
# war
# invite
# form
# immigration
# hear
# gain
# god-given
# patriot
# wise
# official
# growth
# problem
# supreme
# certain
# single
# graceful
# education
# regime
# incredible
# reality
# field
# stagnant
# compete
# draw
# congress
# chance
# coverage
# tackle
# vice
# rule
# 352

# %%
#Using bigrams to identify key phrases that describe the corpus

import nltk
from nltk.collocations import *
bigram_list=[]
bigram_measures = nltk.collocations.BigramAssocMeasures()
for i in a:
    finder = BigramCollocationFinder.from_words(i)
    bigram_list +=finder.nbest(bigram_measures.pmi, 10)
bi_count= nltk.FreqDist(bigram_list).most_common(1000)
common_kp=[]
for i in bi_count:
    for j in range(len(c_list)):
        if c_list[2]==i[0][0] or  c_list[j]==i[0][1] :
            if  i[0] not in common_kp:
                common_kp.append(i[0])
            else:
                pass


common_kp
# Out:
# [(u'keep', u'america'),
#  (u'united', u'state'),
#  (u'member', u'congress'),
#  (u'middle', u'east'),
#  (u'fellow', u'citizen'),
#  (u'men', u'woman'),
#  (u'lead', u'world'),
#  (u'also', u'show'),
#  (u'character', u'country'),
#  (u'african', u'american'),
#  (u'next', u'year'),
#  (u'every', u'year'),
#  (u'natural', u'disaster'),
#  (u'sergeant', u'dan'),
#  (u'defeat', u'enemy'),
#  (u'make', u'sure'),
#  (u'federal', u'government'),
#  (u'nation', u'compete'),
#  (u'security', u'america'),
#  (u'state', u'america'),
#  (u'remain', u'offensive'),
#  (u'ensure', u'america'),
#  (u'continue', u'lead'),
#  (u'congress', u'state'),
#  (u'america', u'continue'),
#  (u'american', u'worker'),
#  (u'build', u'prosperity'),
#  (u"'s", u'youth'),
#  (u'serve', u'interest'),
#  (u'mass', u'murder'),
#  (u"'s", u'child'),
#  (u'congress', u'party'),
#  (u'organize', u'crime'),
#  (u'congress', u'act'),
#  (u'ask', u'congress'),
#  (u'change', u'power'),
#  (u'reality', u'future'),
#  (u'basic', u'institution'),
#  (u'applause', u'state'),
#  (u'society', u'act'),
#  (u'also', u'lead'),
#  (u'prevent', u'terrorist'),
#  (u'decade', u'come'),
#  (u'support', u'democratic'),
#  (u'permanent', u'research'),
#  (u'enter', u'great'),
#  (u'willing', u'act'),
#  (u'policy', u'welfare'),
#  (u'india', u'create'),
#  (u'also', u'fund'),
#  (u'yet', u'difference'),
#  (u'chaos', u'world'),
#  (u'along', u'way'),
#  (u'education', u'support'),
#  (u'enemy', u'freedom'),
#  (u'compete', u'world'),
#  (u'human', u'talent'),
#  (u"'ve", u'call'),
#  (u'cut', u'deficit'),
#  (u'give', u'early'),
#  (u'encouraging', u'economic'),
#  (u'equal', u'hope'),
#  (u'building', u'institution'),
#  (u'affiliate', u'america'),
#  (u'iran', u'nation'),
#  (u'make', u'choice'),
#  (u'give', u'special'),
#  (u'know', u'cost'),
#  (u'history', u'honor'),
#  (u'protect', u'justice'),
#  (u'bless', u'america'),
#  (u'give', u'belief'),
#  (u'rage', u'fight'),
#  (u'accept', u'permanent'),
#  (u'mark', u'official'),
#  (u'choose', u'weapon'),
#  (u'replace', u'resentment'),
#  (u'recent', u'year'),
#  (u'never', u'forget'),
#  (u'well', u'path'),
#  (u'ask', u'join'),
#  (u'stronghold', u'turn'),
#  (u'benefit', u'freedom'),
#  (u'dynamic', u'world'),
#  (u'use', u'constitutional'),
#  (u'compete', u'nation'),
#  (u'far', u'historical'),
#  (u'election', u'government'),
#  (u'fight', u'drug'),
#  (u'fulfil', u'essential'),
#  (u'tackle', u'problem'),
#  (u'reduce', u'growth'),
#  (u'conscience', u'country'),
#  (u'tonight', u'democrat'),
#  (u'regime', u'country'),
#  (u'draperevery', u'time'),
#  (u'crime', u'ask'),
#  (u'broad', u'middle'),
#  (u'strain', u'federal'),
#  (u'behind', u'letter'),
#  (u'seek', u'weapon'),
#  (u'must', u'act'),
#  (u'weapon', u'fear'),
#  (u'keep', u'word'),
#  (u'chief', u'justice'),
#  (u'month', u'fight'),
#  (u'assaulted', u'world'),
#  (u'decisive', u'year'),
#  (u'out-compete', u'american'),
#  (u'urge', u'member'),
#  (u'buy', u'american'),
#  (u'without', u'worry'),
#  (u'moment', u'national'),
#  (u'abortion', u'america'),
#  (u'democratic', u'nation'),
#  (u'suffer', u'chaos'),
#  (u'drop', u'half'),
#  (u'tradition', u'citizen'),
#  (u'enough', u'compete'),
#  (u'hopeful', u'nation'),
#  (u'great', u'change'),
#  (u'make', u'sacrifice'),
#  (u'many', u'leader'),
#  (u'expect', u'elect'),
#  (u'people', u'confident'),
#  (u'19', u'percent'),
#  (u'support', u'american'),
#  (u'mindful', u'history'),
#  (u'rally', u'world'),
#  (u'also', u'great'),
#  (u'among', u'african'),
#  (u'double', u'federal'),
#  (u'also', u'change'),
#  (u'alone', u'wisdom'),
#  (u'responsibility', u'provide'),
#  (u'always', u'secure'),
#  (u'lack', u'military'),
#  (u'must', u'confront'),
#  (u'retirement', u'special'),
#  (u'best', u'way'),
#  (u'address', u'united'),
#  (u'duty', u'hope'),
#  (u'one', u'commitment'),
#  (u'play', u'field'),
#  (u'also', u'address'),
#  (u'reform', u'strengthen'),
#  (u'approve', u'use'),
#  (u'terrorist', u'attack'),
#  (u'u', u'help'),
#  (u'pleased', u'member'),
#  (u'long', u'single'),
#  (u'face', u'death'),
#  (u'11th', u'government'),
#  (u'good', u'work'),
#  (u'make', u'wider'),
#  (u'meet', u'immediate'),
#  (u'call', u'history'),
#  (u'even', u'face'),
#  (u'iraqi', u'show'),
#  (u'people', u'work'),
#  (u'second-rate', u'economy'),
#  (u'iran', u'america'),
#  (u'hope', u'hopeless'),
#  (u'sacrifice', u'show'),
#  (u'reauthorize', u'patriot'),
#  (u'first', u'lady'),
#  (u'help', u'raise'),
#  (u'million', u'american'),
#  (u'freedom', u'hope'),
#  (u'begin', u'keep'),
#  (u'provide', u'health'),
#  (u'family', u'word'),
#  (u'hope', u'trouble'),
#  (u'everywhere', u'united'),
#  (u'stop', u'dramatic'),
#  (u'recognize', u'israel'),
#  (u'liberty', u'europe'),
#  (u'every', u'category'),
#  (u'come', u'end'),
#  (u'secure', u'peace'),
#  (u'brave', u'troop'),
#  (u'bad', u'economy'),
#  (u'worry', u'lose'),
#  (u'mass', u'destruction'),
#  (u'easy', u'life'),
#  (u'wall', u'economy'),
#  (u'bound', u'captive'),
#  (u'disaster', u'let'),
#  (u'dan', u'write'),
#  (u'many', u'special'),
#  (u'see', u'great'),
#  (u'go', u'dictatorship'),
#  (u'right', u'choose'),
#  (u'make', u'country'),
#  (u'140', u'program'),
#  (u'today', u'come'),
#  (u'kill', u'last'),
#  (u'five', u'factory'),
#  (u'ago', u'grateful'),
#  (u'live', u'democratic'),
#  (u'level', u'decision'),
#  (u'across', u'country'),
#  (u'bring', u'murder'),
#  (u'low', u'level'),
#  (u'american', u'fear'),
#  (u'nation', u'grateful'),
#  (u'serve', u'america'),
#  (u'enemy', u'lose'),
#  (u'interest', u'america'),
#  (u'allows', u'temporary'),
#  (u'need', u'support'),
#  (u'toward', u'stagnant'),
#  (u'yet', u'destination'),
#  (u'immense', u'deficit'),
#  (u'import', u'middle'),
#  (u'buy', u'insurance'),
#  (u'envy', u'world'),
#  (u'show', u'world'),
#  (u'fund', u'additional'),
#  (u'history', u'write'),
#  (u'afford', u'insurance'),
#  (u'compassion', u'america'),
#  (u'abandon', u'iraqi'),
#  (u'leadership', u'united'),
#  (u'laura', u'bush'),
#  (u'examine', u'full'),
#  (u'succeed', u'world'),
#  (u'help', u'america'),
#  (u'others', u'day'),
#  (u'action', u'fight'),
#  (u'surveillance', u'program'),
#  (u'exist', u'storm'),
#  (u'act', u'spirit'),
#  (u'disease', u'like'),
#  (u'book', u'write'),
#  (u'another', u'great'),
#  (u'dramatically', u'dangerous'),
#  (u'choose', u'act'),
#  (u'activist', u'court'),
#  (u'fight', u'enemy'),
#  (u'democracies', u'world'),
#  (u'service', u'nation'),
#  (u'confront', u'large'),
#  (u'authority', u'federal'),
#  (u'influence', u'life'),
#  (u'fight', u'president'),
#  (u'friends', u'certain'),
#  (u'remove', u'debris'),
#  (u'bipartisan', u'support'),
#  (u'economic', u'growth'),
#  (u'believe', u'ideal'),
#  (u'every', u'day'),
#  (u'hesitate', u'honor'),
#  (u'economy', u'iraqis'),
#  (u'far', u'federal'),
#  (u'development', u'tax'),
#  (u'human', u'life'),
#  (u'dependence', u'middle'),
#  (u'family', u'use'),
#  (u'child', u'lack'),
#  (u'breakthrough', u'new'),
#  (u'president', u'use'),
#  (u'massive', u'tax'),
#  (u'70,000', u'high'),
#  (u'take', u'declared'),
#  (u'america', u'point'),
#  (u'recover', u'disaster'),
#  (u'advantage', u'world'),
#  (u'accept', u'call'),
#  (u'troop', u'home'),
#  (u'disaster', u'american'),
#  (u'u', u'open'),
#  (u'insurance', u'coverage'),
#  (u'captive', u'terrorist'),
#  (u'boldly', u'fight'),
#  (u'democrat', u'republican'),
#  (u'produce', u'ethanol'),
#  (u'invest', u'zero-emission'),
#  (u'friend', u'desperate'),
#  (u'good', u'start'),
#  (u'people', u'know'),
#  (u'fight', u'aid'),
#  (u'believe', u'god-given'),
#  (u'every', u'child'),
#  (u'country', u'strengthen'),
#  (u'honor', u'support'),
#  (u'lose', u'desire'),
#  (u'fear', u'economic'),
#  (u'seem', u'history'),
#  (u'cut', u'permanent'),
#  (u'regime', u'gain'),
#  (u'radicalism', u'seek'),
#  (u'shelter', u'terrorist'),
#  (u'prosperity', u'country'),
#  (u'reach', u'seek'),
#  (u'require', u'immigration'),
#  (u'patriot', u'act'),
#  (u'three', u'year'),
#  (u'many', u'fellow'),
#  (u'become', u'hopeful'),
#  (u'dramatic', u'progress'),
#  (u'tonight', u'announce'),
#  (u'ground', u'iraqi'),
#  (u'address', u'deep'),
#  (u'provide', u'new'),
#  (u'2006', u'united'),
#  (u'centralize', u'power'),
#  (u'washington', u'support'),
#  (u'destruction', u'country'),
#  (u'destination', u'history'),
#  (u'join', u'fight'),
#  (u'heartless', u'system'),
#  (u'pretend', u'keep'),
#  (u'national', u'election'),
#  (u'continue', u'reach'),
#  (u'nation', u'middle'),
#  (u'act', u'provide'),
#  (u'hiv', u'half'),
#  (u'official', u'retirement'),
#  (u'point', u'choose'),
#  (u'freedom', u'fight'),
#  (u'terrorists', u'palestinian'),
#  (u'u', u'show'),
#  (u'victory', u'come'),
#  (u'increase', u'tax'),
#  (u'choose', u'lead'),
#  (u'fine', u'president'),
#  (u'good', u'life'),
#  (u'achieve', u'half'),
#  (u'launch', u'attack'),
#  (u'give', u'nation'),
#  (u'recognize', u'matchless'),
#  (u'like', u'reflect'),
#  (u'one', u'day'),
#  (u'many', u'american'),
#  (u'leave', u'vicious'),
#  (u'improve', u'quality'),
#  (u'federal', u'commitment'),
#  (u"'s", u'like'),
#  (u'back', u'wait'),
#  (u'poorly', u'fulfil'),
#  (u'behind', u'act'),
#  (u'leave', u'woman'),
#  (u'respect', u'respect'),
#  (u'child', u'school'),
#  (u'neighbor', u'join'),
#  (u'temporary', u'tax'),
#  (u'determine', u'enemy'),
#  (u'forward', u'economic'),
#  (u'go', u'keep'),
#  (u'institution', u'last'),
#  (u'lebanon', u'egypt'),
#  (u'world', u'economy'),
#  (u'peace', u'way'),
#  (u'yet', u'tax'),
#  (u'everyone', u'tonight'),
#  (u'iraq', u'use'),
#  (u'across', u'broad'),
#  (u'list', u'aid'),
#  (u'confront', u'rise'),
#  (u'hope', u'glad'),
#  (u'effort', u'help'),
#  (u'want', u'escape'),
#  (u'guest', u'worker'),
#  (u'improve', u'environment'),
#  (u'people', u'turn'),
#  (u'form', u'economic'),
#  (u'help', u'iraqis'),
#  (u'state', u'grateful'),
#  (u'billion', u'next'),
#  (u'strike', u'terrorist'),
#  (u'adjust', u'military'),
#  (u'citizen', u'fight'),
#  (u'hand', u'fight'),
#  (u'boomer', u'turn'),
#  (u'like', u'american'),
#  (u'home', u'america'),
#  (u'year', u'nation'),
#  (u'generate', u'new'),
#  (u'elect', u'official'),
#  (u'help', u'friend'),
#  (u'lead', u'freedom'),
#  (u'problem', u'america'),
#  (u'session', u'congress'),
#  (u'camp', u'help'),
#  (u'last', u'year'),
#  (u'develop', u'clean'),
#  (u'aid', u'fellow'),
#  (u'leadership', u'world'),
#  (u'tonight', u'let'),
#  (u'entitlement', u'problem'),
#  (u'crime', u'human'),
#  (u'every', u'life'),
#  (u'institution', u'let'),
#  (u'steward', u'tax'),
#  (u'peaceful', u'change'),
#  (u'felt', u'excluded'),
#  (u'god', u'bless'),
#  (u'call', u'america'),
#  (u'forget', u'sacrifice'),
#  (u'drug', u'use'),
#  (u'courageous', u'woman'),
#  (u'stronger', u'immigration'),
#  (u'belief', u'america'),
#  (u'make', u'permanent')]

# %% [markdown]
# In this exercise I had adopted the State of the union speech and had tried to use simple NLP techniques to summerize.  I experimented with Named entities and ended up Lemmatising the words accroding to their POS and usied frequency unigrams to describe the corpus using key words. I further used the lemmatised and key noun phrase and words to extract common bigrams that I believe does a reasonable job of describing the corpus
